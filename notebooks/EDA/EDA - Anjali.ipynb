# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("../../data/water_potability.csv")
data.head()
# Out:
#          ph    Hardness        Solids  Chloramines     Sulfate  Conductivity  \
# 0       NaN  204.890455  20791.318981     7.300212  368.516441    564.308654
# 1  3.716080  129.422921  18630.057858     6.635246         NaN    592.885359
# 2  8.099124  224.236259  19909.541732     9.275884         NaN    418.606213
# 3  8.316766  214.373394  22018.417441     8.059332  356.886136    363.266516
# 4  9.092223  181.101509  17978.986339     6.546600  310.135738    398.410813
#
#    Organic_carbon  Trihalomethanes  Turbidity  Potability
# 0       10.379783        86.990970   2.963135           0
# 1       15.180013        56.329076   4.500656           0
# 2       16.868637        66.420093   3.055934           0
# 3       18.436524       100.341674   4.628771           0
# 4       11.558279        31.997993   4.075075           0

# %%
data.shape
# Out:
# (3276, 10)

# %%
data = data.dropna()
data.head()
# Out:
#           ph    Hardness        Solids  Chloramines     Sulfate  Conductivity  \
# 3   8.316766  214.373394  22018.417441     8.059332  356.886136    363.266516
# 4   9.092223  181.101509  17978.986339     6.546600  310.135738    398.410813
# 5   5.584087  188.313324  28748.687739     7.544869  326.678363    280.467916
# 6  10.223862  248.071735  28749.716544     7.513408  393.663396    283.651634
# 7   8.635849  203.361523  13672.091764     4.563009  303.309771    474.607645
#
#    Organic_carbon  Trihalomethanes  Turbidity  Potability
# 3       18.436524       100.341674   4.628771           0
# 4       11.558279        31.997993   4.075075           0
# 5        8.399735        54.917862   2.559708           0
# 6       13.789695        84.603556   2.672989           0
# 7       12.363817        62.798309   4.401425           0

# %%
data.shape
# Out:
# (2011, 10)

# %%
data.info()   #To get metadata of the table
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2011 entries, 3 to 3271
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ph               2011 non-null   float64
#  1   Hardness         2011 non-null   float64
#  2   Solids           2011 non-null   float64
#  3   Chloramines      2011 non-null   float64
#  4   Sulfate          2011 non-null   float64
#  5   Conductivity     2011 non-null   float64
#  6   Organic_carbon   2011 non-null   float64
#  7   Trihalomethanes  2011 non-null   float64
#  8   Turbidity        2011 non-null   float64
#  9   Potability       2011 non-null   int64
# dtypes: float64(9), int64(1)
# memory usage: 172.8 KB

# %%
data.describe()    #Gives the statistical information of the data
# Out:
#                 ph     Hardness        Solids  Chloramines      Sulfate  \
# count  2011.000000  2011.000000   2011.000000  2011.000000  2011.000000
# mean      7.085990   195.968072  21917.441374     7.134338   333.224672
# std       1.573337    32.635085   8642.239815     1.584820    41.205172
# min       0.227499    73.492234    320.942611     1.390871   129.000000
# 25%       6.089723   176.744938  15615.665390     6.138895   307.632511
# 50%       7.027297   197.191839  20933.512750     7.143907   332.232177
# 75%       8.052969   216.441070  27182.587067     8.109726   359.330555
# max      14.000000   317.338124  56488.672413    13.127000   481.030642
#
#        Conductivity  Organic_carbon  Trihalomethanes    Turbidity   Potability
# count   2011.000000     2011.000000      2011.000000  2011.000000  2011.000000
# mean     426.526409       14.357709        66.400859     3.969729     0.403282
# std       80.712572        3.324959        16.077109     0.780346     0.490678
# ...

# %%
data['Potability'].value_counts()   #Frequency of the output types
# Out:
# 0    1200
# 1     811
# Name: Potability, dtype: int64

# %%
sns.countplot(data=data, x="Potability")
# Out:
# <AxesSubplot:xlabel='Potability', ylabel='count'>

# %%
plt.figure(dpi=150)
sns.boxplot(x="Potability", y = "ph", data=data)
# Out:
# <AxesSubplot:xlabel='Potability', ylabel='ph'>

# %%
plt.figure(dpi=150)
sns.boxplot(x="Potability", y = "Hardness", data=data)
# Out:
# <AxesSubplot:xlabel='Potability', ylabel='Hardness'>

# %%
plt.figure(dpi=150)
sns.boxplot(x="Potability", y = "Solids", data=data)
# Out:
# <AxesSubplot:xlabel='Potability', ylabel='Solids'>

# %%
plt.figure(dpi=150)
sns.boxplot(x="Potability", y = "Chloramines", data=data)
# Out:
# <AxesSubplot:xlabel='Potability', ylabel='Chloramines'>

# %%
plt.figure(dpi=150)
sns.boxplot(x="Potability", y = "Sulfate", data=data)
# Out:
# <AxesSubplot:xlabel='Potability', ylabel='Sulfate'>

# %%
plt.figure(dpi=150)
sns.boxplot(x="Potability", y = "Conductivity", data=data)
# Out:
# <AxesSubplot:xlabel='Potability', ylabel='Conductivity'>

# %%
plt.figure(dpi=150)
sns.boxplot(x="Potability", y = "Organic_carbon", data=data)
# Out:
# <AxesSubplot:xlabel='Potability', ylabel='Organic_carbon'>

# %%
plt.figure(dpi=150)
sns.boxplot(x="Potability", y = "Trihalomethanes", data=data)
# Out:
# <AxesSubplot:xlabel='Potability', ylabel='Trihalomethanes'>

# %%
plt.figure(dpi=150)
sns.boxplot(x="Potability", y = "Turbidity", data=data)
# Out:
# <AxesSubplot:xlabel='Potability', ylabel='Turbidity'>

# %%
sns.scatterplot(x='ph', y='Hardness', data=data, hue="Potability")
# Out:
# <AxesSubplot:xlabel='ph', ylabel='Hardness'>

# %%
sns.scatterplot(x='Solids', y='Turbidity', data=data, hue="Potability")
# Out:
# <AxesSubplot:xlabel='Solids', ylabel='Turbidity'>

# %%
sns.pairplot(data, hue="Potability")

# %%
sns.heatmap(data.corr(), annot=True) #To observe correlation between attributes
# Out:
# <AxesSubplot:>

# %%
from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(data['ph'], data['Hardness'], data['Potability'], c=data['Potability'])
